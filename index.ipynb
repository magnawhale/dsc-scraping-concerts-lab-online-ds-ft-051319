# %% [markdown]
# # Scraping Concerts - Lab
#
# ## Introduction
#
# Now that you've seen how to scrape a simple website, it's time to again practice those skills on a full-fledged site!
# In this lab, you'll practice your scraping skills on a music website: https://www.residentadvisor.net.
# ## Objectives
#
# You will be able to:
# * Scrape events from a website
# * Follow links to those events to retrieve further information
# * Clean and store scraped data

# %% [markdown]
# ## View the Website
#
# For this lab, you'll be scraping the https://www.residentadvisor.net website. Start by navigating to the events page [here](https://www.residentadvisor.net/events) in your browser.
#
# <img src="images/ra.png">

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
html_page = requests.get('https://www.residentadvisor.net/events/us/newyork')
soup = BeautifulSoup(html_page.content, 'html.parser')

# %%
#Load the https://www.residentadvisor.net/events page in your browser.

# %% [markdown]
# ## Open the Inspect Element Feature
#
# Next, open the inspect element feature from your web browser in order to preview the underlying HTML associated with the page.

# %%
#Open the inspect element feature in your browser

# %% [markdown]
# ## Write a Function to Scrape all of the Events on the Given Page Events Page
#
# The function should return a Pandas DataFrame with columns for the Event_Name, Venue, Event_Date and Number_of_Attendees.

# %%
def get_items(soup):
    items = soup.findAll('article', class_='highlight-top')
    return items
items = get_items(soup)
items[0]
# Out:
# <article class="highlight-top">
# <p>Thu, 13 Jun 2019</p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1275181"><img class="nohide" src="/images/events/flyer/2019/6/us-0613-1275181-list.jpg"/></a>
# <p class="counter nohide">
# <span>615</span> attending
# </p>
# <a ga-event-action="popular-events" ga-event-category="events-page" ga-on="click" href="/events/1275181">
# <h1>
# Morgana [free entry]: Atish, John Tejada Live, Nicone, Patricio
# </h1>
# </a>
# <p class="copy nohide">
# <a href="\club.aspx?id=105938">Brooklyn Mirage</a>
# </p>
# </article>

# %%
def get_names_venues(soup):
    event_names = [article.find('h1').text.strip() for article in soup.findAll('article', attrs={'itemtype':'http://data-vocabulary.org/Event'})]
    names = []
    venues = []
    for e in event_names:
        names.append(e.split(' at ')[0])
        venues.append(e.split(' at ')[1])
    return names, venues
e_names, e_venues = get_names_venues(soup)

# %%
def get_dates(soup):
    dates = []
    event_dates = [article.find('time').text.strip() for article in soup.findAll('article', attrs={'itemtype':'http://data-vocabulary.org/Event'})]
    for d in event_dates:
        dates.append(d.split('T')[0])
    return dates
e_dates = get_dates(soup)

# %%
def get_attending(soup):
    attending = []
    event_attending = [article.find('p') for article in soup.findAll('article', attrs={'itemtype':'http://data-vocabulary.org/Event'})]
    for a in event_attending:
        try:
            attending.append(int(a.find('span').text))
        except:
            attending.append(a)
    return attending
e_attending = get_attending(soup)

# %%
df = pd.DataFrame([e_names, e_venues, e_dates, e_attending]).transpose()
df.columns = (["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"])
df.head()
# Out:
#                                           Event_Name                  Venue  \
# 0    Delivery. Carlos Alkalina, Playsuit, Pjay, Bytz                Ms. Yoo
# 1                                          Cancelled   14B Rooftop / Lounge
# 2               Tempo with Steve Tek (Open to Close)           TBA Brooklyn
# 3    Feel Real with DJ Disciple, Ejoe Wilson Friends            Rumpus Room
# 4  Small Rave 019 - Xcreenplay (Live)/ Perris/ Fe...  Bossa Nova Civic Club
#
#    Event_Date Number_of_Attendees
# 0  2019-06-11                   5
# 1  2019-06-11                   2
# 2  2019-06-11                   2
# 3  2019-06-11                   1
# 4  2019-06-11                None

# %%
def scrape_events(events_page_url):
    html_page = requests.get(events_page_url)
    soup = BeautifulSoup(html_page.content, 'html.parser')
    e_names, e_venues = get_names_venues(soup)
    e_dates = get_dates(soup)
    e_attending = get_attending(soup)
    df = pd.DataFrame([e_names, e_venues, e_dates, e_attending]).transpose()
    df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]
    return df

# %%
scrape_events('https://www.residentadvisor.net/events/us/newyork')
# Out:
#                                             Event_Name  \
# 0      Delivery. Carlos Alkalina, Playsuit, Pjay, Bytz
# 1                                            Cancelled
# 2                 Tempo with Steve Tek (Open to Close)
# 3      Feel Real with DJ Disciple, Ejoe Wilson Friends
# 4    Small Rave 019 - Xcreenplay (Live)/ Perris/ Fe...
# 5                     Feel Free: Grand Atrium + Buskko
# 6    Nacho Rojas' B2b2b2b2b2b2b Bday Bash [actual B...
# 7                                    Party Party Party
# 8    Full Flex with DJ Swagger, Klein Zage b2b Joey...
# 9    Ūndisclosed - Ryan Crosson, Jeff Veliz, Martin...
# 10                                      One Night Only
# 11   Expansions NYC Special Guests Josh Milan, Ian ...
# 12              Laylit Days with Wake Island and Saphe
# 13                               Open Decks Session 67
# 14                                Will Shore Residency
# 15                                      2nd Wednesdays
# 16   Morgana [free entry]: Atish, John Tejada Live,...
# 17   Susanne Bartsch presents: Club Heartbreak with...
# 18   Ascend: The Scumfrog, Special Guest, Gio Israe...
# 19                 Body Music Therapy presents LDY OSC
# 20                            Omnom / Vnssa - Biome002
# 21                   Hello Sailor Record Release Party
# 22   Brooklyn Record Exchange Residency with DJ Kra...
# 23                        Air A Danser: w/ Sacha Mambo
# 24                              Tropical Past & Future
# 25                                          Groundwire
# 26                                          Shak Shaka
# 27    Anything Goes: Stelios Vassiloudis, Dysco & Krsn
# 28                                    The WARPER PARTY
# 29                                      Like That Recs
# ..                                                 ...
# 100            Ubiquity Soul Summer House Music Series
# 101  PFR Live: Longer, Luvworks, Secondary Five, Ha...
# 102                     13th Hour presents! Ricky Razu
# 103  Flanger ⥸ with 2Lanes, Oscar Huang, Dj Worldvi...
# 104                         Esscalation Music Festival
# 105   Caché Life presents a Night with Brooklyn Hustle
# 106                  Assembly: Suzi Analogue, Pamela Z
# 107                                 Good-Natured Sound
# 108                           Jennifer Walshe & Wobbly
# 109                              Select Summer Fridays
# 110            Rufus Gibson presents: Titonton Duvante
# 111                    Xmpz / Fana / Haruka / dj Celes
# 112                                   Soulful Sessions
# 113         United Spirits-Butch SOS Birthday Beast621
# 114                      Nacho Rojas's Bday Boat Party
# 115  Feel Free NYC presents Refresh Rate - Panooc (...
# 116          Move for Wolves with MANIK + Son of Sound
# 117                                  Soul Summit Music
# 118  Justus Worldwide presents: Coney Island Boardw...
# 119  Dirtybird BBQ - Brooklyn (Claude Vonstroke, Ju...
# 120                                      Mister Sunday
# 121                                          Vinyl BBQ
# 122                                      PA-RT Liberty
# 127                             TBA Brooklyn  2019-06-16                None
# 128                          Brooklyn Mirage  2019-06-17                 265
# 129                                  Le Bain  2019-06-17                   2
#
# [130 rows x 4 columns]

# %% [markdown]
# ## Write a Function to Retrieve the URL for the Next Page

# %%
def next_page(url):
    next_page_url = soup.find(id="liNext")
    if next_page_url:
        return str("https://www.residentadvisor.net" + next_page_url.find('a').attrs['href'])
    else:
        return None
    return next_page_url

# %%
print(next_page('https://www.residentadvisor.net/events/us/newyork'))
# Out:
# https://www.residentadvisor.net/events/us/newyork/week/2019-06-18

# %% [markdown]
# ## Scrape the Next 1000 Events for Your Area
#
# Display the data sorted by the number of attendees. If there is a tie for the number attending, sort by event date.

# %%
def get_names(soup, names):
    event_names = [article.find('h1').text.strip() for article in soup.findAll('article', attrs={'itemtype':'http://data-vocabulary.org/Event'})]
    for e in event_names:
        names.append(e.split(' at ')[0])
    return names


def get_venues(soup, venues):
    event_venues = [article.find('h1').text.strip() for article in soup.findAll('article', attrs={'itemtype':'http://data-vocabulary.org/Event'})]
    for e in event_venues:
        venues.append(e.split(' at ')[1])
    return venues
    

def get_dates(soup, dates):
    event_dates = [article.find('time').text.strip() for article in soup.findAll('article', attrs={'itemtype':'http://data-vocabulary.org/Event'})]
    for d in event_dates:
        dates.append(d.split('T')[0])
    return dates


def get_attending(soup, attending):
    event_attending = [article.find('p') for article in soup.findAll('article', attrs={'itemtype':'http://data-vocabulary.org/Event'})]
    for a in event_attending:
        try:
            attending.append(int(a.find('span').text))
        except:
            attending.append(a)
    return attending    

    
def events_to_df(names, venues, dates, attending):
    df = pd.DataFrame([names, venues, dates, attending]).transpose()
    df.columns = ["Event_Name", "Venue", "Event_Date", "Number_of_Attendees"]
    return df


# def next_page(url):
#     next_page_url = soup.find(id="liNext")
#     if next_page_url:
#         return str("https://www.residentadvisor.net" + next_page_url.find('a').attrs['href'])
#     else:
#         return None
#     return next_page_url


def next_page(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    url_ext = soup.find('a', attrs={'ga-event-action':"Next "}).attrs['href']
    next_page_url = "https://www.residentadvisor.net" + url_ext
    #Your code here
    return next_page_url



def parse_url(url, names=[], venues=[], dates=[], attending=[]):
    names=names
    venues=venues
    dates=dates
    attending=attending
    url = url
    html_page = requests.get(url)
    soup = BeautifulSoup(html_page.content, 'html.parser')
    names += get_names(soup, names)
    venues += get_venues(soup, venues)
    dates += get_dates(soup, dates)
    attending += get_attending(soup, attending)
    for i in range (0,10000):
        while len(names) < 1000:
            url = next_page(url)
            html_page = requests.get(url)
            soup = BeautifulSoup(html_page.content, 'html.parser')
            names += get_names(soup, names)
            venues += get_venues(soup, venues)
            dates += get_dates(soup, dates)
            attending += get_attending(soup, attending)
    return names, venues, dates, attending

# %%
url = "https://www.residentadvisor.net/events/us/newyork"

# %%
names, venues, dates, attending = parse_url(url)

# %%
df1 = events_to_df(names, venues, dates, attending).copy()
df1[360:920]
# Out:
#                                             Event_Name  \
# 360      718 Sessions Returns to the Elsewhere Rooftop
# 361          Body Music Therapy with Nihal Ramchandani
# 362   Rollup 1 Year Anniversary: Takaya Nagase zorenLo
# 363    Delivery. Carlos Alkalina, Playsuit, Pjay, Bytz
